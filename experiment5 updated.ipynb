# %%
import torch
from PIL import Image
import matplotlib.pyplot as plt

# Load the YOLOv5 model (small version for faster inference)
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')

# Image path (change to your image path)
image_path = r"E:\downloads\WhatsApp Image 2024-11-26 at 01.26.00_b354dcd7.jpg"  # Replace this with your image path

# Perform inference on the image
results = model(image_path)

# Display the results
results.show()  # This will show the image with detected objects

# Print the detected objects
print(f"Detected objects: {results.names}")
print(f"Predicted bounding boxes and confidence scores: {results.pred[0]}")

# Optionally, save the output image with bounding boxes
results.save()  # Saves the image with bounding boxes in the current directory
# Out:
# Using cache found in C:\Users\91889/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2024-11-25 Python-3.11.5 torch-2.5.1+cpu CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...
# C:\Users\91889/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# <PIL.Image.Image image mode=RGB size=800x448>
# Saved 1 image to runs\detect\exp8
# ...

# %%
import torch
from PIL import Image
import matplotlib.pyplot as plt

# Load the YOLOv5 model (small version for faster inference)
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')

# Image path (change to your image path)
image_path = r"E:\downloads\dl image.jpg"  # Replace this with your image path

# Perform inference on the image
results = model(image_path)

# Display the results
results.show()  # This will show the image with detected objects

# Print the detected objects
print(f"Detected objects: {results.names}")
print(f"Predicted bounding boxes and confidence scores: {results.pred[0]}")

# Optionally, save the output image with bounding boxes
results.save()  # Saves the image with bounding boxes in the current directory
# Out:
# Using cache found in C:\Users\91889/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2024-11-25 Python-3.11.5 torch-2.5.1+cpu CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...
# C:\Users\91889/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# <PIL.Image.Image image mode=RGB size=1024x1024>
# Saved 1 image to runs\detect\exp9
# ...

# %%
import torch
import cv2
import os

# Load the YOLOv5 model (small version for faster inference)
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')

# Input video path
input_video_path = r"E:\downloads\3727445-hd_1920_1080_30fps.mp4"

# Output directory and video path
output_directory = r"E:\object detection"
os.makedirs(output_directory, exist_ok=True)  # Ensure the output directory exists
output_video_path = os.path.join(output_directory, "output_video.mp4")

# Open the video file
cap = cv2.VideoCapture(input_video_path)

# Get video properties
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))
fourcc = cv2.VideoWriter_fourcc(*"mp4v")  # Codec for MP4 format
out = cv2.VideoWriter(output_video_path, fourcc, fps, (frame_width, frame_height))

# Process video frame by frame
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Convert frame to RGB for YOLOv5 (OpenCV loads frames in BGR format)
    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    # Perform inference
    results = model(rgb_frame)

    # Get the processed frame with bounding boxes
    result_frame = results.render()[0]  # Rendered frame as NumPy array
    result_frame = cv2.cvtColor(result_frame, cv2.COLOR_RGB2BGR)  # Convert back to BGR

    # Write the frame to the output video
    out.write(result_frame)

    # Optionally display the frame in a window (comment out if not needed)
    cv2.imshow("YOLOv5 Object Detection", result_frame)
    if cv2.waitKey(1) & 0xFF == ord("q"):  # Press 'q' to stop
        break

# Release resources
cap.release()
out.release()
cv2.destroyAllWindows()

print(f"Processed video saved at: {output_video_path}")
# Out:
# Using cache found in C:\Users\91889/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2024-11-25 Python-3.11.5 torch-2.5.1+cpu CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...
# C:\Users\91889/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# C:\Users\91889/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# C:\Users\91889/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# ...
